# %%
grocery = [Eggs, Avocados, Cookies, Hot_Pepper_Jam, Blueberries, Broccoli]
print (grocery)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 grocery = [Eggs, Avocados, Cookies, Hot_Pepper_Jam, Blueberries, Broccoli]
#       2 print (grocery)
#
# NameError: name 'Eggs' is not defined
