# %%
def welcome():
  print("👋 Welcome to McDonald's Drive-Thru!")
  print("Here’s our menu:")
  print("1. 🍔 Cheeseburger")
  print("2. 🍟 Fries")
  print("3. 🥤 Soda")
  print("4. 🍦 Ice Cream")
  print("5. 🍪 Cookie")


def get_item(number):
  if number == 1:
    return "🍔 Cheeseburger"
  elif number == 2:
    return "🍟 Fries"
  elif number == 3:
    return "🥤 Soda"
  elif number == 4:
    return "🍦 Ice Cream"
  elif number == 5:
    return "🍪 Cookie"
  else:
    return "❌ Not on the menu!"

print ('welcome()')
choices = int(input("enter your oder number "))
print (get_item(choices))
# Out:
# welcome()
# enter your oder number  3
# 🥤 Soda
