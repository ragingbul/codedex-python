# %%
for i in range(102):
  print("I will not use Snapchat in class")
# Out:
# I will not use Snapchat in class
# I will not use Snapchat in class
# I will not use Snapchat in class
# I will not use Snapchat in class
# I will not use Snapchat in class
# I will not use Snapchat in class
# I will not use Snapchat in class
# I will not use Snapchat in class
# I will not use Snapchat in class
# I will not use Snapchat in class
# I will not use Snapchat in class
# I will not use Snapchat in class
# I will not use Snapchat in class
# I will not use Snapchat in class
# I will not use Snapchat in class
# I will not use Snapchat in class
# I will not use Snapchat in class
# I will not use Snapchat in class
# I will not use Snapchat in class
# I will not use Snapchat in class
# I will not use Snapchat in class
# I will not use Snapchat in class
# I will not use Snapchat in class
# I will not use Snapchat in class
# I will not use Snapchat in class
# I will not use Snapchat in class
# I will not use Snapchat in class
# I will not use Snapchat in class
# ...
