# %%
for i in range(99, 0, -1):
  print(f'{i} bottles of beer on th wall')
  print(f'{i} bottles')
  print(f'take one down and pass it around')
# Out:
# 99 bottles of beer on th wall
# 99 bottles
# take one down and pass it around
# 98 bottles of beer on th wall
# 98 bottles
# take one down and pass it around
# 97 bottles of beer on th wall
# 97 bottles
# take one down and pass it around
# 96 bottles of beer on th wall
# 96 bottles
# take one down and pass it around
# 95 bottles of beer on th wall
# 95 bottles
# take one down and pass it around
# 94 bottles of beer on th wall
# 94 bottles
# take one down and pass it around
# 93 bottles of beer on th wall
# 93 bottles
# take one down and pass it around
# 92 bottles of beer on th wall
# 92 bottles
# take one down and pass it around
# 91 bottles of beer on th wall
# 91 bottles
# take one down and pass it around
# 90 bottles of beer on th wall
# 90 bottles
# take one down and pass it around
# 89 bottles of beer on th wall
# 89 bottles
# take one down and pass it around
# 88 bottles of beer on th wall
# 88 bottles
# take one down and pass it around
# 87 bottles of beer on th wall
# ...
