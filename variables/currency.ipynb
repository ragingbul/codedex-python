# %%
pesos = int(input('how much pesos? '))
soles = int(input('how much soles? '))
reais = int(input('how much reais? '))
a = pesos / 4024.57
b = soles / 3.52 
c = reais / 5.45
usd = (a + b + c)
print ( usd )2
# Out:
# how much pesos?  230
# how much soles?  450
# how much reais?  700
# 256.338425025884
